# %%
# Out:
# ...
#   Using cached EEGRAPH-0.1.17-py3-none-any.whl (29 kB)
# ...
#   Using cached numpy-1.21.1.zip (10.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached kaleido-0.2.1-py2.py3-none-win_amd64.whl (65.9 MB)
# ...
#   Using cached mne-1.2.0-py3-none-any.whl (7.6 MB)
# ...
#   Using cached scot-0.2.1-py2.py3-none-any.whl (57 kB)
# ...
#   Using cached scipy-1.10.1-cp310-cp310-win_amd64.whl (42.5 MB)
# ...
# Failed to build numpy
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [315 lines of output]
#   setup.py:63: RuntimeWarning: NumPy 1.21.1 may not yet support Python 3.10.
#     warnings.warn(
#   Running from numpy source directory.
#   Processing numpy/random\_bounded_integers.pxd.in
# ...

# %%
import eegraph
G = eegraph.Graph()
file_path = 'exported_control_filtered_raw.edf'
G.load_data(path = file_path, electrode_montage_path = 'Standard-10-20-Cap19new.ced')

graphs, connectivity_matrix = G.modelate(window_size = 2, connectivity = 'pearson_correlation')
# Out:
# Extracting EDF parameters from c:\Users\Ahmed Guebsi\Desktop\ahmed_files\XAI_ADHD\data\exported_adhd_raw.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 19
# Sample rate: 128.0 Hz.
# Duration: 337.992 seconds.
# Channel Names: ['Fp1', 'Fp2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'T7', 'C3', 'Cz', 'C4', 'T8', 'P7', 'P3', 'Pz', 'P4', 'P8']
# Model Data.
# Pearson_correlation_Estimator()
# ...

# %%
graphs, connectivity_matrix = G.modelate(window_size = 2, connectivity = 'power_spectrum', bands = ['delta','theta','alpha'])
# Out:
# Model Data.
# Power_spectrum_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [True, True, True, False, False]
# ...

# %%
G.visualize_html(graphs[0], 'graph_3')

#print(connectivity_matrix)
